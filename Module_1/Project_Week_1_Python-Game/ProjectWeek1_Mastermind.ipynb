# %% [markdown]
# # Mastermind pseudo code

# %%
# Begin

# Welcome message AM-11

Print “Hey welcome to IronMastermind !!"

# Randomise color combination AM-12

Define color dictionnary:
G : Green, B : Blue, W : White, B : Black, Y : Yellow, R : Red, P : Pink

Create an empty list G_combination

Import random library

Create a list with the keys from the color dictionary

random.choice(key_list, 4) 

#Variable Initialisation AM-13

Initialise the computer_answer  (Number of white | misplaced , Number of blacks | Good one’s) : (0,0)

Initialise the count_turns at 0
 
answer = (0,0)
count_turns = 0
# Loop start
while answer != (4,0):

    # Ask the user for a combination AM-14

    Loop untill input_valid

    print """"Please enter a suite of 4 colors;

    Use ‘k' for Black ; ‘g’ for Green ; ‘b' for Blue ; ‘w’ for White ; ‘y’ for Yellow ; 'r’ for Red ; 'p’ for Pink

    For exemple : type gbwy and press enter for Green-Blue-White-Yellow""""

    Test the validity of the input ,  G_user_combination

    If input_valid = False, print 'Wrong input'
    count_turns += 1

    # Test the combination and build answer AM-15

    -Count the number of good placed

    L_good = 0

    for i in range(0,4):

        if G_combination[i] == G_user_combination[i]:
            L_good += 1

    -Count the number of misplaced elements

    L_miss_placed = 0

    for i in G_combination:
        if i in G_user_combination:
            L_miss_placed += 1
    L_miss_placed = L_miss_placed - L_good        

    -Build an answer 

    answer = (L_good, L_miss_placed)

    #Display answer AM-16

    Build the answer message:

    if L_good != 0 or L_miss_placed != 0:
        print “You have 'x' elements at the right place,
        print You have 'x' elements at the wrong place”
        print You have 'x' times left
    else:
        “no elements are present”
        print You have 'x' times left

    if count_turns == 12:
        break

if answer == (4,0):
    # Display win message AM-17
    “Bravo ! you master my mind !!”
else:
    # Display lose message AM-18
    “No more try left …….. You loose”
