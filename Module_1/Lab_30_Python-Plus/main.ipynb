# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources (README.md file)
# - Happy learning!

# %%
# Libraries
import pandas as pd

# %% [markdown]
# # Challenge 1 - Practice index functions
#
# In this challenge, we will practice the advanced functions introduced in the lesson. However, before we start, we will load and evaluate our dataset.
#
# Load the dataset from the `Admission_Predict.csv` file (in the same folder as this notebook) into an `admissions` DataFrame.

# %%
# import data set from Ironhack's database
admissions=pd.read_csv('Admission_Predict.csv')

# %% [markdown]
# Remove trailing spaces at the end of the column names if there are any.

# %%
admissions.rename(columns=lambda x: x.strip(), inplace=True)
admissions
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0             1        337          118                  4  4.5  4.5  9.65
# 1             2        316          104                  3  3.0  3.5  8.00
# 2             3        322          110                  3  3.5  2.5  8.67
# 3             4        314          103                  2  2.0  3.0  8.21
# 4             5        330          115                  5  4.5  3.0  9.34
# ..          ...        ...          ...                ...  ...  ...   ...
# 380         381        324          110                  3  3.5  3.5  9.04
# 381         382        325          107                  3  3.0  3.5  9.11
# 382         383        330          116                  4  5.0  4.5  9.45
# 383         384        312          103                  3  3.5  4.0  8.78
# 384         385        333          117                  4  5.0  4.0  9.66
#
#      Research  Chance of Admit
# 0           1             0.92
# 1           1             0.72
# 2           1             0.80
# 3           0             0.65
# 4           1             0.90
# ..        ...              ...
# 380         1             0.82
# 381         1             0.84
# 382         1             0.91
# 383         0             0.67
# 384         1             0.95
#
# [385 rows x 9 columns]

# %% [markdown]
# Let's evaluate the dataset by looking at the `head` function.

# %%
admissions.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        316          104                  3  3.0  3.5  8.00
# 2           3        322          110                  3  3.5  2.5  8.67
# 3           4        314          103                  2  2.0  3.0  8.21
# 4           5        330          115                  5  4.5  3.0  9.34
#
#    Research  Chance of Admit
# 0         1             0.92
# 1         1             0.72
# 2         1             0.80
# 3         0             0.65
# 4         1             0.90

# %% [markdown]
# Before beginning to work with this dataset and evaluating graduate admissions data, we will verify that there is no missing data in the dataset. Do this in the cell below.

# %%
admissions.isna().sum()

#no missing data in the dataset
# Out:
# Serial No.           0
# GRE Score            0
# TOEFL Score          0
# University Rating    0
# SOP                  0
# LOR                  0
# CGPA                 0
# Research             0
# Chance of Admit      0
# dtype: int64

# %% [markdown]
# Interestingly, there is a column that uniquely identifies the applicants. This column is the serial number column. Instead of having our own index, we should make this column our index. Do this in the cell below. Keep the column in the dataframe in addition to making it an index.

# %%
admissions = admissions.set_index('Serial No.', drop=False)
admissions
# Out:
#             Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  \
# Serial No.
# 1                    1        337          118                  4  4.5  4.5
# 2                    2        316          104                  3  3.0  3.5
# 3                    3        322          110                  3  3.5  2.5
# 4                    4        314          103                  2  2.0  3.0
# 5                    5        330          115                  5  4.5  3.0
# ...                ...        ...          ...                ...  ...  ...
# 381                381        324          110                  3  3.5  3.5
# 382                382        325          107                  3  3.0  3.5
# 383                383        330          116                  4  5.0  4.5
# 384                384        312          103                  3  3.5  4.0
# 385                385        333          117                  4  5.0  4.0
#
#             CGPA  Research  Chance of Admit
# Serial No.
# 1           9.65         1             0.92
# 2           8.00         1             0.72
# 3           8.67         1             0.80
# 4           8.21         0             0.65
# 5           9.34         1             0.90
# ...          ...       ...              ...
# 381         9.04         1             0.82
# 382         9.11         1             0.84
# 383         9.45         1             0.91
# 384         8.78         0             0.67
# 385         9.66         1             0.95
#
# [385 rows x 9 columns]

# %% [markdown]
# Turns out that `GRE Score` and `CGPA` also uniquely identify the data. Show this in the cell below.

# %%
#in order to check this, we're gonna check if there are duplicates:

admissions.duplicated(["GRE Score", "CGPA"]).sum()

#There isn't, so it means that the couple ["GRE Score", "CGPA"] uniquely identifies the data
# Out:
# 0

# %% [markdown]
# Replace the index with an index comprised of two columns - `GRE Score` and `CGPA`. Remove the columns from the dataset as well. Make sure to use `inplace=True`.

# %% [markdown]
# Now change the index back to a sequence starting at zero using the `reset_index` function. Make sure to use `inplace=True`.

# %%
admissions.set_index(['GRE Score','CGPA'], inplace=True, drop=True)

# %%
admissions.reset_index(inplace=True)
admissions
# Out:
#      GRE Score  CGPA  Serial No.  TOEFL Score  University Rating  SOP  LOR  \
# 0          337  9.65           1          118                  4  4.5  4.5
# 1          316  8.00           2          104                  3  3.0  3.5
# 2          322  8.67           3          110                  3  3.5  2.5
# 3          314  8.21           4          103                  2  2.0  3.0
# 4          330  9.34           5          115                  5  4.5  3.0
# ..         ...   ...         ...          ...                ...  ...  ...
# 380        324  9.04         381          110                  3  3.5  3.5
# 381        325  9.11         382          107                  3  3.0  3.5
# 382        330  9.45         383          116                  4  5.0  4.5
# 383        312  8.78         384          103                  3  3.5  4.0
# 384        333  9.66         385          117                  4  5.0  4.0
#
#      Research  Chance of Admit
# 0           1             0.92
# 1           1             0.72
# 2           1             0.80
# 3           0             0.65
# 4           1             0.90
# ..        ...              ...
# 380         1             0.82
# 381         1             0.84
# 382         1             0.91
# 383         0             0.67
# 384         1             0.95
#
# [385 rows x 9 columns]

# %% [markdown]
# # Challenge 2 - Building a composite indicator
#
# In this part of the lab, we would build two different composite indicator, using some normalization functions.
#
# Let's start by finding the number of rows where the CGPA is higher than 9 and the student has conducted research.

# %%
admissions.loc[(admissions["CGPA"] > 9) & (admissions["Research"] > 0)]
# Out:
#      GRE Score  CGPA  Serial No.  TOEFL Score  University Rating  SOP  LOR  \
# 0          337  9.65           1          118                  4  4.5  4.5
# 4          330  9.34           5          115                  5  4.5  3.0
# 10         328  9.10          11          112                  4  4.0  4.5
# 19         328  9.50          20          116                  5  5.0  5.0
# 20         334  9.70          21          119                  5  5.0  4.5
# ..         ...   ...         ...          ...                ...  ...  ...
# 379        329  9.23         380          111                  4  4.5  4.0
# 380        324  9.04         381          110                  3  3.5  3.5
# 381        325  9.11         382          107                  3  3.0  3.5
# 382        330  9.45         383          116                  4  5.0  4.5
# 384        333  9.66         385          117                  4  5.0  4.0
#
#      Research  Chance of Admit
# 0           1             0.92
# 4           1             0.90
# 10          1             0.78
# 19          1             0.94
# 20          1             0.95
# ..        ...              ...
# 379         1             0.89
# 380         1             0.82
# 381         1             0.84
# 382         1             0.91
# 384         1             0.95
#
# [101 rows x 9 columns]

# %% [markdown]
# Now return all the rows where the CGPA is greater than 9 and the SOP score is less than 3.5. Find the mean chance of admit for these applicants.

# %%
condition = (admissions["CGPA"] >= 9) & (admissions["SOP"] <= 3.5)

relevant_rows = admissions.loc[condition]
relevant_rows
# Out:
#      GRE Score  CGPA  Serial No.  TOEFL Score  University Rating  SOP  LOR  \
# 28         338  9.40          29          118                  4  3.0  4.5
# 62         327  9.02          63          114                  3  3.0  3.0
# 64         318  9.22          65          109                  3  3.5  4.0
# 99         326  9.05         100          112                  3  3.5  3.0
# 102        338  9.46         103          117                  4  3.5  4.5
# 123        326  9.10         124          112                  3  3.5  3.0
# 132        318  9.12         133          109                  1  3.5  3.5
# 140        326  9.11         141          114                  3  3.0  3.0
# 170        319  9.04         171          110                  3  3.5  3.5
# 217        324  9.01         218          111                  4  3.0  3.0
# 231        325  9.04         232          114                  3  3.5  3.0
# 239        316  9.00         240           99                  2  2.5  3.0
# 311        326  9.14         312          116                  3  3.5  4.0
# 356        324  9.22         357          110                  3  3.5  3.0
# 380        324  9.04         381          110                  3  3.5  3.5
# 381        325  9.11         382          107                  3  3.0  3.5
#
#      Research  Chance of Admit
# 28          1             0.91
# 62          0             0.61
# 64          1             0.68
# 99          1             0.74
# 102         1             0.91
# 123         1             0.84
# 132         0             0.78
# 140         1             0.83
# 170         0             0.82
# 217         1             0.82
# 231         1             0.76
# 239         0             0.70
# 311         1             0.81
# 356         1             0.89
# 380         1             0.82
# 381         1             0.84

# %% [markdown]
# We would like to create a deciding factor column for each student. We standardize several columns and then pick the most important factor from a lookup table. If the standardized value is above 0.8, the student will be accepted.
#
# We will start by creating a standardized column for `CGPA`, `GRE Score` and `LOR`. We will name these columns `CGPA_std`, `GRE_std`, and `LOR_std` respecively.
#
# Recall that standardizing a column is done by subtracting the mean of the column from all observations in the column and then dividing each observation in the column by the column's standard deviation.
#
# In the cell below, write a standardization function (a function that takes a column as input and returns a standardized column as output). Make sure to use the `numpy` versions of mean and standard deviation.

# %%
import numpy as np

def standardize(col):
    return (col - col.mean()) / np.std(col)

# %% [markdown]
# Now create the standardized columns `CGPA_std`, `GRE_std`, and `LOR_std` and add them to the `admissions` dataframe.

# %%
admissions["CGPA_std"] = standardize(admissions["CGPA"])
admissions["GRE_std"] = standardize(admissions["GRE Score"])
admissions["LOR_std"] = standardize(admissions["LOR"])

admissions
# Out:
#      GRE Score  CGPA  Serial No.  TOEFL Score  University Rating  SOP  LOR  \
# 0          337  9.65           1          118                  4  4.5  4.5
# 1          316  8.00           2          104                  3  3.0  3.5
# 2          322  8.67           3          110                  3  3.5  2.5
# 3          314  8.21           4          103                  2  2.0  3.0
# 4          330  9.34           5          115                  5  4.5  3.0
# ..         ...   ...         ...          ...                ...  ...  ...
# 380        324  9.04         381          110                  3  3.5  3.5
# 381        325  9.11         382          107                  3  3.0  3.5
# 382        330  9.45         383          116                  4  5.0  4.5
# 383        312  8.78         384          103                  3  3.5  4.0
# 384        333  9.66         385          117                  4  5.0  4.0
#
#      Research  Chance of Admit  CGPA_std   GRE_std   LOR_std
# 0           1             0.92  1.750174  1.755663  1.193197
# 1           1             0.72 -0.992501 -0.063450  0.076840
# 2           1             0.80  0.121191  0.456297 -1.039517
# 3           0             0.65 -0.643433 -0.236698 -0.481338
# 4           1             0.90  1.234884  1.149292 -0.481338
# ..        ...              ...       ...       ...       ...
# 380         1             0.82  0.736216  0.629546  0.076840
# 381         1             0.84  0.852571  0.716170  0.076840
# 382         1             0.91  1.417729  1.149292  1.193197
# 383         0             0.67  0.304036 -0.409947  0.635019
# 384         1             0.95  1.766796  1.409165  0.635019
#
# [385 rows x 12 columns]

# %% [markdown]
# Now we will try two different ways of making the decision whether or not to accept the student:
# 1. A weighted average of `CGPA_std`, `GRE_std`, and `LOR_std`.
# 2. The best score among `CGPA_std`, `GRE_std`, and `LOR_std`.

# %% [markdown]
# ### Indicator 1.
#
# Add a `score_1` column to the `admissions` dataframe, which is a weighted average, computed like this:
#
# 0.4 * `CGPA_std` + 0.3 * `GRE_std` + 0.3 * `LOR_std`

# %%
admissions["score_1"] = 0.4 * admissions["CGPA_std"] + 0.3 * admissions["GRE_std"] + 0.3 * admissions["LOR_std"]
admissions
# Out:
#      GRE Score  CGPA  Serial No.  TOEFL Score  University Rating  SOP  LOR  \
# 0          337  9.65           1          118                  4  4.5  4.5
# 1          316  8.00           2          104                  3  3.0  3.5
# 2          322  8.67           3          110                  3  3.5  2.5
# 3          314  8.21           4          103                  2  2.0  3.0
# 4          330  9.34           5          115                  5  4.5  3.0
# ..         ...   ...         ...          ...                ...  ...  ...
# 380        324  9.04         381          110                  3  3.5  3.5
# 381        325  9.11         382          107                  3  3.0  3.5
# 382        330  9.45         383          116                  4  5.0  4.5
# 383        312  8.78         384          103                  3  3.5  4.0
# 384        333  9.66         385          117                  4  5.0  4.0
#
#      Research  Chance of Admit  CGPA_std   GRE_std   LOR_std   score_1
# 0           1             0.92  1.750174  1.755663  1.193197  1.584728
# 1           1             0.72 -0.992501 -0.063450  0.076840 -0.392983
# 2           1             0.80  0.121191  0.456297 -1.039517 -0.126489
# 3           0             0.65 -0.643433 -0.236698 -0.481338 -0.472784
# 4           1             0.90  1.234884  1.149292 -0.481338  0.694340
# ..        ...              ...       ...       ...       ...       ...
# 380         1             0.82  0.736216  0.629546  0.076840  0.506402
# 381         1             0.84  0.852571  0.716170  0.076840  0.578932
# 382         1             0.91  1.417729  1.149292  1.193197  1.269838
# 383         0             0.67  0.304036 -0.409947  0.635019  0.189136
# 384         1             0.95  1.766796  1.409165  0.635019  1.319974
#
# [385 rows x 13 columns]

# %% [markdown]
# ### Indicator 2.
#
# Add a `score_2` column to the `admissions` dataframe, which is the best (highest) score among `CGPA_std`, `GRE_std`, and `LOR_std`.

# %%
admissions["score_2"] = admissions[["CGPA_std", "GRE_std", "LOR_std"]].max(axis = 1)
admissions
# Out:
#      GRE Score  CGPA  Serial No.  TOEFL Score  University Rating  SOP  LOR  \
# 0          337  9.65           1          118                  4  4.5  4.5
# 1          316  8.00           2          104                  3  3.0  3.5
# 2          322  8.67           3          110                  3  3.5  2.5
# 3          314  8.21           4          103                  2  2.0  3.0
# 4          330  9.34           5          115                  5  4.5  3.0
# ..         ...   ...         ...          ...                ...  ...  ...
# 380        324  9.04         381          110                  3  3.5  3.5
# 381        325  9.11         382          107                  3  3.0  3.5
# 382        330  9.45         383          116                  4  5.0  4.5
# 383        312  8.78         384          103                  3  3.5  4.0
# 384        333  9.66         385          117                  4  5.0  4.0
#
#      Research  Chance of Admit  CGPA_std   GRE_std   LOR_std   score_1  \
# 0           1             0.92  1.750174  1.755663  1.193197  1.584728
# 1           1             0.72 -0.992501 -0.063450  0.076840 -0.392983
# 2           1             0.80  0.121191  0.456297 -1.039517 -0.126489
# 3           0             0.65 -0.643433 -0.236698 -0.481338 -0.472784
# 4           1             0.90  1.234884  1.149292 -0.481338  0.694340
# ..        ...              ...       ...       ...       ...       ...
# 380         1             0.82  0.736216  0.629546  0.076840  0.506402
# 381         1             0.84  0.852571  0.716170  0.076840  0.578932
# 382         1             0.91  1.417729  1.149292  1.193197  1.269838
# 383         0             0.67  0.304036 -0.409947  0.635019  0.189136
# 384         1             0.95  1.766796  1.409165  0.635019  1.319974
#
#       score_2
# 0    1.755663
# 1    0.076840
# 2    0.456297
# 3   -0.236698
# 4    1.234884
# ..        ...
# 380  0.736216
# 381  0.852571
# 382  1.417729
# 383  0.635019
# 384  1.766796
#
# [385 rows x 14 columns]

# %% [markdown]
# ### Decision

# %% [markdown]
# Create a column called `decision_1` with the admission decision based on score 1: `True` if `score_1` is greater than 0.8 and `False` otherwise.
#
# Similarty, create a `decision_2` column that contains the decision for score 2.

# %%
admissions["decision_1"] = admissions["score_1"] > 0.8
admissions["decision_2"] = admissions["score_2"] > 0.8
admissions
# Out:
#      GRE Score  CGPA  Serial No.  TOEFL Score  University Rating  SOP  LOR  \
# 0          337  9.65           1          118                  4  4.5  4.5
# 1          316  8.00           2          104                  3  3.0  3.5
# 2          322  8.67           3          110                  3  3.5  2.5
# 3          314  8.21           4          103                  2  2.0  3.0
# 4          330  9.34           5          115                  5  4.5  3.0
# ..         ...   ...         ...          ...                ...  ...  ...
# 380        324  9.04         381          110                  3  3.5  3.5
# 381        325  9.11         382          107                  3  3.0  3.5
# 382        330  9.45         383          116                  4  5.0  4.5
# 383        312  8.78         384          103                  3  3.5  4.0
# 384        333  9.66         385          117                  4  5.0  4.0
#
#      Research  Chance of Admit  CGPA_std   GRE_std   LOR_std   score_1  \
# 0           1             0.92  1.750174  1.755663  1.193197  1.584728
# 1           1             0.72 -0.992501 -0.063450  0.076840 -0.392983
# 2           1             0.80  0.121191  0.456297 -1.039517 -0.126489
# 3           0             0.65 -0.643433 -0.236698 -0.481338 -0.472784
# 4           1             0.90  1.234884  1.149292 -0.481338  0.694340
# ..        ...              ...       ...       ...       ...       ...
# 380         1             0.82  0.736216  0.629546  0.076840  0.506402
# 381         1             0.84  0.852571  0.716170  0.076840  0.578932
# 382         1             0.91  1.417729  1.149292  1.193197  1.269838
# 383         0             0.67  0.304036 -0.409947  0.635019  0.189136
# 384         1             0.95  1.766796  1.409165  0.635019  1.319974
#
#       score_2  decision_1  decision_2
# 0    1.755663        True        True
# 1    0.076840       False       False
# 2    0.456297       False       False
# 3   -0.236698       False       False
# 4    1.234884       False        True
# ..        ...         ...         ...
# 380  0.736216       False       False
# 381  0.852571       False        True
# 382  1.417729        True        True
# 383  0.635019       False       False
# 384  1.766796        True        True
#
# [385 rows x 16 columns]

# %% [markdown]
# How many applicants will be accepted to the program using each scoring method?

# %%
Score_1_method = admissions["decision_1"].sum()
Score_2_method = admissions["decision_2"].sum()
Score_1_method, Score_2_method
# Out:
# (81, 133)

# %% [markdown]
# # Challenge 3 - Method Chaining
#
# To increase our coding efficiency, let's make a number of changes to our dataframe in one line of code.
#
# In the cell below, remove all non character symbols from the column names, replace all spaces in column names to underscores, and change all upper case characters to lower case.

# %%
admissions.rename(columns=lambda x: x.strip().lower().replace(' ', '_').replace(r'\W', ''), inplace=True)
admissions
# Out:
#      gre_score  cgpa  serial_no.  toefl_score  university_rating  sop  lor  \
# 0          337  9.65           1          118                  4  4.5  4.5
# 1          316  8.00           2          104                  3  3.0  3.5
# 2          322  8.67           3          110                  3  3.5  2.5
# 3          314  8.21           4          103                  2  2.0  3.0
# 4          330  9.34           5          115                  5  4.5  3.0
# ..         ...   ...         ...          ...                ...  ...  ...
# 380        324  9.04         381          110                  3  3.5  3.5
# 381        325  9.11         382          107                  3  3.0  3.5
# 382        330  9.45         383          116                  4  5.0  4.5
# 383        312  8.78         384          103                  3  3.5  4.0
# 384        333  9.66         385          117                  4  5.0  4.0
#
#      research  chance_of_admit  cgpa_std   gre_std   lor_std   score_1  \
# 0           1             0.92  1.750174  1.755663  1.193197  1.584728
# 1           1             0.72 -0.992501 -0.063450  0.076840 -0.392983
# 2           1             0.80  0.121191  0.456297 -1.039517 -0.126489
# 3           0             0.65 -0.643433 -0.236698 -0.481338 -0.472784
# 4           1             0.90  1.234884  1.149292 -0.481338  0.694340
# ..        ...              ...       ...       ...       ...       ...
# 380         1             0.82  0.736216  0.629546  0.076840  0.506402
# 381         1             0.84  0.852571  0.716170  0.076840  0.578932
# 382         1             0.91  1.417729  1.149292  1.193197  1.269838
# 383         0             0.67  0.304036 -0.409947  0.635019  0.189136
# 384         1             0.95  1.766796  1.409165  0.635019  1.319974
#
#       score_2  decision_1  decision_2
# 0    1.755663        True        True
# 1    0.076840       False       False
# 2    0.456297       False       False
# 3   -0.236698       False       False
# 4    1.234884       False        True
# ..        ...         ...         ...
# 380  0.736216       False       False
# 381  0.852571       False        True
# 382  1.417729        True        True
# 383  0.635019       False       False
# 384  1.766796        True        True
#
# [385 rows x 16 columns]

# %% [markdown]
# In the cell below, give all student with a university rating of 4 or higher a 10 point boost on their GRE score and split the column into 4 bins called `A` (highest GRE), `B`, `C` and `D` (lowest GRE).
#
# You can use Pandas `cut` function. Assign this new score to the variable `adjusted_gre`. Do not modify the original GRE column.

# %%
admissions.loc[admissions["university_rating"] >= 4, "adjusted_gre"] = admissions["gre_score"] + 10

admissions['bin'] = pd.cut(admissions['gre_score'], bins=4, labels=["A", "B", "C", "D"])

# %%
admissions
# Out:
#      gre_score  cgpa  serial_no.  toefl_score  university_rating  sop  lor  \
# 0          337  9.65           1          118                  4  4.5  4.5
# 1          316  8.00           2          104                  3  3.0  3.5
# 2          322  8.67           3          110                  3  3.5  2.5
# 3          314  8.21           4          103                  2  2.0  3.0
# 4          330  9.34           5          115                  5  4.5  3.0
# ..         ...   ...         ...          ...                ...  ...  ...
# 380        324  9.04         381          110                  3  3.5  3.5
# 381        325  9.11         382          107                  3  3.0  3.5
# 382        330  9.45         383          116                  4  5.0  4.5
# 383        312  8.78         384          103                  3  3.5  4.0
# 384        333  9.66         385          117                  4  5.0  4.0
#
#      research  chance_of_admit  cgpa_std   gre_std   lor_std   score_1  \
# 0           1             0.92  1.750174  1.755663  1.193197  1.584728
# 1           1             0.72 -0.992501 -0.063450  0.076840 -0.392983
# 2           1             0.80  0.121191  0.456297 -1.039517 -0.126489
# 3           0             0.65 -0.643433 -0.236698 -0.481338 -0.472784
# 4           1             0.90  1.234884  1.149292 -0.481338  0.694340
# ..        ...              ...       ...       ...       ...       ...
# 380         1             0.82  0.736216  0.629546  0.076840  0.506402
# 381         1             0.84  0.852571  0.716170  0.076840  0.578932
# 382         1             0.91  1.417729  1.149292  1.193197  1.269838
# 383         0             0.67  0.304036 -0.409947  0.635019  0.189136
# 384         1             0.95  1.766796  1.409165  0.635019  1.319974
#
#       score_2  decision_1  decision_2  adjusted_gre bin
# 0    1.755663        True        True         347.0   D
# 1    0.076840       False       False           NaN   C
# 2    0.456297       False       False           NaN   C
# 3   -0.236698       False       False           NaN   B
# 4    1.234884       False        True         340.0   D
# ..        ...         ...         ...           ...  ..
# 380  0.736216       False       False           NaN   C
# 381  0.852571       False        True           NaN   C
# 382  1.417729        True        True         340.0   D
# 383  0.635019       False       False           NaN   B
# 384  1.766796        True        True         343.0   D
#
# [385 rows x 18 columns]
